# %%
# Dependencies and Setup
from census import Census
# from config import (census_key, gkey)
import gmaps
import numpy as np
import pandas as pd
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt
from pprint import pprint

# Import API key

from config import g_key
Token = 'kIhFoumHoyDXCthBMuPBenpMdGZfmqJI'

# %%
stationid=['GHCND:USW00003102',
'GHCND:USC00047470',
'GHCND:USC00042494',
'GHCND:USR0000CDVA',
'GHCND:USR0000CDUN',
'GHCND:USS0020L06S',
'GHCND:USC00047723',
'GHCND:USR0000CMOR',
'GHCND:USC00043251',
'GHCND:USC00043256',
'GHCND:USR0000CBZE',
'GHCND:USR0000CASC',
'GHCND:USR0000CBLQ',
'GHCND:USW00093112',
'GHCND:US1CASD0100',
'GHCND:US1CASD0038',
'GHCND:USR0000COAB',
'GHCND:US1CASH0009',
'GHCND:USC00042467',
'GHCND:USC00041916',
'GHCND:USC00045233',
'GHCND:US1CAMA0008',
'GHCND:US1CABT0032',
'GHCND:US1CABT0010',
'GHCND:USR0000CLDR',
'GHCND:USR0000CSNL',
'GHCND:USC00042920',
'GHCND:USR0000CABS',
'GHCND:USC00041886',
'GHCND:USC00043761',
'GHCND:USC00047085',
'GHCND:US1CAPM0002',
'GHCND:USR0000CBOG',
'GHCND:USC00041244',
'GHCND:USW00053144',
'GHCND:USR0000CDMC',
'GHCND:US1CATM0005',
'GHCND:USC00048353',
'GHCND:USS0020H06S',
'GHCND:USR0000CTIM',
'GHCND:USR0000CJUN',
'GHCND:USR0000CBUL',
'GHCND:USC00041476']
stationid
# Out:
# ['GHCND:USW00003102',
#  'GHCND:USC00047470',
#  'GHCND:USC00042494',
#  'GHCND:USR0000CDVA',
#  'GHCND:USR0000CDUN',
#  'GHCND:USS0020L06S',
#  'GHCND:USC00047723',
#  'GHCND:USR0000CMOR',
#  'GHCND:USC00043251',
#  'GHCND:USC00043256',
#  'GHCND:USR0000CBZE',
#  'GHCND:USR0000CASC',
#  'GHCND:USR0000CBLQ',
#  'GHCND:USW00093112',
#  'GHCND:US1CASD0100',
#  'GHCND:US1CASD0038',
#  'GHCND:USR0000COAB',
#  'GHCND:US1CASH0009',
#  'GHCND:USC00042467',
#  'GHCND:USC00041916',
#  'GHCND:USC00045233',
#  'GHCND:US1CAMA0008',
#  'GHCND:US1CABT0032',
#  'GHCND:US1CABT0010',
#  'GHCND:USR0000CLDR',
#  'GHCND:USR0000CSNL',
#  'GHCND:USC00042920',
#  'GHCND:USR0000CABS',
#  'GHCND:USC00041886',
#  'GHCND:USC00043761',
#  'GHCND:USC00047085',
#  'GHCND:US1CAPM0002',
#  'GHCND:USR0000CBOG',
#  'GHCND:USC00041244',
#  'GHCND:USW00053144',
#  'GHCND:USR0000CDMC',
#  'GHCND:US1CATM0005',
#  'GHCND:USC00048353',
#  'GHCND:USS0020H06S',
#  'GHCND:USR0000CTIM',
#  'GHCND:USR0000CJUN',
#  'GHCND:USR0000CBUL',
#  'GHCND:USC00041476']

# %%
county = 'San Diego'
base_url = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?'
query_url = base_url+f'locationid=ZIP:28801&startdate=2010-05-01&enddate=2010-05-01'

response = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TMAX&units=standard&limit=1000&locationid=FIPS:06073&startdate=2005-01-01&enddate=2005-12-30',headers = {'token':Token}).json()
pprint(response)
#data?datasetid=GSOM&datatypeid=TAVG&units=standard&limit=1000&locationid=FIPS:06&startdate=2006-01-01&enddate=2006-02-01
# Out:
# {'metadata': {'resultset': {'count': 14816, 'limit': 1000, 'offset': 1}},
#  'results': [{'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00040983',
#               'value': 64.0},
#              {'attributes': ',,0,1700',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00041424',
#               'value': 54.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00042239',
#               'value': 42.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00042706',
#               'value': 61.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00042863',
#               'value': 65.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00043914',
#               'value': 46.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00044412',
#               'value': 49.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00044735',
#               'value': 59.0},
#              {'attributes': ',,0,1530',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00046386',
#               'value': 64.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00046657',
#               'value': 38.0},
#              {'attributes': ',,0,1500',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00047228',
#               'value': 58.0},
#              {'attributes': ',,0,1630',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00047741',
#               'value': 58.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00047874',
#               'value': 64.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00049378',
#               'value': 60.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CALP',
#               'value': 60.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CAMM',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CCAM',
#               'value': 52.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CCAS',
#               'value': 54.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CDES',
#               'value': 53.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CGOO',
#               'value': 61.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CJUL',
#               'value': 45.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CLAG',
#               'value': 43.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CLSF',
#               'value': 67.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000COKG',
#               'value': 53.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CPHI',
#               'value': 49.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CPOT',
#               'value': 56.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CRCH',
#               'value': 45.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CSMI',
#               'value': 59.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CTAL',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USR0000CTAR',
#               'value': 59.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USW00003131',
#               'value': 60.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USW00003154',
#               'value': 60.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USW00003164',
#               'value': 52.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USW00003177',
#               'value': 58.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USW00003178',
#               'value': 62.0},
#              {'attributes': ',,0,2400',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USW00023188',
#               'value': 61.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USW00053120',
#               'value': 55.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USW00053121',
#               'value': 59.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USW00093112',
#               'value': 59.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00040136',
#               'value': 54.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00040983',
#               'value': 61.0},
#              {'attributes': ',,0,1700',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00041424',
#               'value': 51.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00042239',
#               'value': 44.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00042706',
#               'value': 57.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00042863',
#               'value': 61.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00043914',
#               'value': 52.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00044412',
#               'value': 42.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00044735',
#               'value': 60.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00045968',
#               'value': 41.0},
#              {'attributes': ',,0,1530',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00046386',
#               'value': 62.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00046657',
#               'value': 39.0},
#              {'attributes': ',I,0,1500',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00047228',
#               'value': 54.0},
#              {'attributes': ',,0,1630',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00047741',
#               'value': 61.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00047874',
#               'value': 59.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USC00049378',
#               'value': 60.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CALP',
#               'value': 56.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CAMM',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CCAM',
#               'value': 49.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CCAS',
#               'value': 48.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CDES',
#               'value': 49.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CGOO',
#               'value': 54.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CJUL',
#               'value': 43.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CLAG',
#               'value': 39.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CLSF',
#               'value': 62.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000COKG',
#               'value': 55.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CPHI',
#               'value': 45.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CPOT',
#               'value': 56.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CRCH',
#               'value': 44.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CSMI',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CTAL',
#               'value': 56.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CTAR',
#               'value': 56.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USR0000CVAL',
#               'value': 56.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USW00003131',
#               'value': 57.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USW00003154',
#               'value': 60.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USW00003164',
#               'value': 49.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USW00003177',
#               'value': 58.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USW00003178',
#               'value': 57.0},
#              {'attributes': ',,0,2400',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USW00023188',
#               'value': 59.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USW00053120',
#               'value': 52.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USW00053121',
#               'value': 60.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USW00093107',
#               'value': 57.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-02T00:00:00',
#               'station': 'GHCND:USW00093112',
#               'value': 58.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00040136',
#               'value': 53.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00040983',
#               'value': 61.0},
#              {'attributes': ',,0,1700',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00041424',
#               'value': 49.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00041758',
#               'value': 61.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00042239',
#               'value': 43.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00042706',
#               'value': 59.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00042709',
#               'value': 66.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00042863',
#               'value': 57.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00043914',
#               'value': 47.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00044412',
#               'value': 39.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00044735',
#               'value': 58.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00045968',
#               'value': 37.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00046377',
#               'value': 60.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00046657',
#               'value': 36.0},
#              {'attributes': ',,0,1500',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00047228',
#               'value': 55.0},
#              {'attributes': ',,0,1630',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00047741',
#               'value': 58.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00047874',
#               'value': 59.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USC00049378',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CALP',
#               'value': 55.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CAMM',
#               'value': 56.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CCAM',
#               'value': 47.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CCAS',
#               'value': 51.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CDES',
#               'value': 47.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CGOO',
#               'value': 55.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CJUL',
#               'value': 43.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CLAG',
#               'value': 38.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CLSF',
#               'value': 65.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000COKG',
#               'value': 47.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CPHI',
#               'value': 49.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CPOT',
#               'value': 50.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CRCH',
#               'value': 44.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CSMI',
#               'value': 57.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CTAL',
#               'value': 56.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CTAR',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USR0000CVAL',
#               'value': 57.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USW00003131',
#               'value': 58.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USW00003154',
#               'value': 60.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USW00003164',
#               'value': 49.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USW00003177',
#               'value': 57.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USW00003178',
#               'value': 60.0},
#              {'attributes': ',,0,2400',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USW00023188',
#               'value': 60.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USW00053120',
#               'value': 55.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USW00053121',
#               'value': 60.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-03T00:00:00',
#               'station': 'GHCND:USW00093112',
#               'value': 58.0},
#              {'attributes': ',I,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00040136',
#               'value': 44.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00040983',
#               'value': 52.0},
#              {'attributes': ',,0,1700',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00041424',
#               'value': 40.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00041758',
#               'value': 57.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00042239',
#               'value': 42.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00042706',
#               'value': 59.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00042709',
#               'value': 60.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00042863',
#               'value': 55.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00043914',
#               'value': 45.0},
#              {'attributes': ',I,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00044412',
#               'value': 34.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00044735',
#               'value': 58.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00046377',
#               'value': 57.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00046657',
#               'value': 34.0},
#              {'attributes': ',I,0,1500',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00047228',
#               'value': 48.0},
#              {'attributes': ',,0,1630',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00047741',
#               'value': 53.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00047874',
#               'value': 55.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USC00049378',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CALP',
#               'value': 42.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CAMM',
#               'value': 49.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CCAM',
#               'value': 39.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CCAS',
#               'value': 42.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CDES',
#               'value': 37.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CGOO',
#               'value': 45.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CJUL',
#               'value': 35.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CLAG',
#               'value': 31.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CLSF',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000COKG',
#               'value': 39.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CPHI',
#               'value': 37.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CPOT',
#               'value': 42.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CRCH',
#               'value': 35.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CSMI',
#               'value': 52.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CTAL',
#               'value': 47.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USR0000CTAR',
#               'value': 49.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USW00003131',
#               'value': 52.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USW00003154',
#               'value': 52.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USW00003164',
#               'value': 41.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USW00003177',
#               'value': 51.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USW00003178',
#               'value': 54.0},
#              {'attributes': ',,0,2400',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USW00023188',
#               'value': 54.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USW00053120',
#               'value': 48.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USW00053121',
#               'value': 53.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USW00093107',
#               'value': 53.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-04T00:00:00',
#               'station': 'GHCND:USW00093112',
#               'value': 54.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00040136',
#               'value': 53.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00040983',
#               'value': 60.0},
#              {'attributes': ',,0,1700',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00041424',
#               'value': 51.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00041758',
#               'value': 62.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00042239',
#               'value': 33.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00042706',
#               'value': 66.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00042709',
#               'value': 52.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00042863',
#               'value': 59.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00043914',
#               'value': 36.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00044412',
#               'value': 41.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00046377',
#               'value': 59.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00046657',
#               'value': 35.0},
#              {'attributes': ',,0,1500',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00047228',
#               'value': 56.0},
#              {'attributes': ',,0,1630',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00047741',
#               'value': 59.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00047874',
#               'value': 62.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USC00049378',
#               'value': 59.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CALP',
#               'value': 57.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CAMM',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CCAM',
#               'value': 51.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CCAS',
#               'value': 53.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CDES',
#               'value': 52.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CGOO',
#               'value': 59.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CJUL',
#               'value': 43.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CLAG',
#               'value': 44.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CLSF',
#               'value': 70.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000COKG',
#               'value': 54.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CPHI',
#               'value': 50.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CPOT',
#               'value': 56.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CRCH',
#               'value': 46.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CSMI',
#               'value': 59.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CTAL',
#               'value': 59.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CTAR',
#               'value': 59.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USR0000CVAL',
#               'value': 60.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USW00003131',
#               'value': 59.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USW00003154',
#               'value': 59.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USW00003164',
#               'value': 50.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USW00003177',
#               'value': 59.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USW00003178',
#               'value': 60.0},
#              {'attributes': ',,0,2400',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USW00023188',
#               'value': 61.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USW00053120',
#               'value': 54.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USW00053121',
#               'value': 59.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USW00093107',
#               'value': 58.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-05T00:00:00',
#               'station': 'GHCND:USW00093112',
#               'value': 58.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00040983',
#               'value': 59.0},
#              {'attributes': ',,0,1700',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00041424',
#               'value': 52.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00041758',
#               'value': 62.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00042239',
#               'value': 39.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00042706',
#               'value': 59.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00042709',
#               'value': 63.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00042863',
#               'value': 59.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00043914',
#               'value': 50.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00044412',
#               'value': 41.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00044735',
#               'value': 59.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00046377',
#               'value': 57.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00046657',
#               'value': 37.0},
#              {'attributes': ',,0,1500',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00047228',
#               'value': 55.0},
#              {'attributes': ',,0,1630',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00047741',
#               'value': 57.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00047874',
#               'value': 62.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USC00049378',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CALP',
#               'value': 56.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CAMM',
#               'value': 59.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CCAM',
#               'value': 51.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CCAS',
#               'value': 51.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CDES',
#               'value': 48.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CGOO',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CJUL',
#               'value': 45.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CLAG',
#               'value': 45.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CLSF',
#               'value': 64.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000COKG',
#               'value': 54.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CPHI',
#               'value': 46.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CPOT',
#               'value': 54.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CRCH',
#               'value': 44.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CSMI',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CTAL',
#               'value': 59.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CTAR',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USR0000CVAL',
#               'value': 60.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USW00003131',
#               'value': 57.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USW00003154',
#               'value': 58.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-06T00:00:00',
#               'station': 'GHCND:USW00003164',
#               'value': 50.0},
#              {'attributes': ',,W,',
# ...
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USR0000CLSF',
#               'value': 64.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USR0000COKG',
#               'value': 73.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USR0000CPHI',
#               'value': 63.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USR0000CPOT',
#               'value': 74.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USR0000CRCH',
#               'value': 57.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USR0000CSMI',
#               'value': 72.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USR0000CTAL',
#               'value': 75.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USR0000CTAR',
#               'value': 75.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USW00003131',
#               'value': 76.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USW00003154',
#               'value': 68.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USW00003164',
#               'value': 66.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USW00003177',
#               'value': 64.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USW00003178',
#               'value': 74.0},
#              {'attributes': ',,0,2400',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USW00023188',
#               'value': 70.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USW00053120',
#               'value': 74.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USW00053121',
#               'value': 64.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USW00093107',
#               'value': 73.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-22T00:00:00',
#               'station': 'GHCND:USW00093112',
#               'value': 66.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00040136',
#               'value': 74.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00040983',
#               'value': 76.0},
#              {'attributes': ',,0,1700',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00041424',
#               'value': 61.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00042239',
#               'value': 56.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00042706',
#               'value': 75.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00042863',
#               'value': 75.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00043914',
#               'value': 63.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00044412',
#               'value': 57.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00044735',
#               'value': 73.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00046377',
#               'value': 61.0},
#              {'attributes': ',,0,1530',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00046386',
#               'value': 77.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00046657',
#               'value': 58.0},
#              {'attributes': ',,0,1500',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00047228',
#               'value': 75.0},
#              {'attributes': ',,0,1630',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00047741',
#               'value': 67.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00047874',
#               'value': 80.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USC00049378',
#               'value': 72.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CALP',
#               'value': 74.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CAMM',
#               'value': 74.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CCAM',
#               'value': 64.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CCAS',
#               'value': 74.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CDES',
#               'value': 68.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CGOO',
#               'value': 74.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CJUL',
#               'value': 58.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CLAG',
#               'value': 54.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CLSF',
#               'value': 71.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000COKG',
#               'value': 71.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CPHI',
#               'value': 64.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CPOT',
#               'value': 72.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CRCH',
#               'value': 59.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CSMI',
#               'value': 73.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CTAL',
#               'value': 76.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USR0000CTAR',
#               'value': 73.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USW00003131',
#               'value': 73.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USW00003154',
#               'value': 73.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USW00003164',
#               'value': 65.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USW00003177',
#               'value': 69.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USW00003178',
#               'value': 75.0},
#              {'attributes': ',,0,2400',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USW00023188',
#               'value': 74.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USW00053120',
#               'value': 73.0},
#              {'attributes': ',,W,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USW00053121',
#               'value': 67.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USW00093107',
#               'value': 71.0},
#              {'attributes': ',,X,',
#               'datatype': 'TMAX',
#               'date': '2005-01-23T00:00:00',
#               'station': 'GHCND:USW00093112',
#               'value': 69.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00040136',
#               'value': 66.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00040983',
#               'value': 68.0},
#              {'attributes': ',,0,1700',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00041424',
#               'value': 64.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00041758',
#               'value': 75.0},
#              {'attributes': ',,0,0800',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00042239',
#               'value': 55.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00042706',
#               'value': 75.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00042709',
#               'value': 79.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00042863',
#               'value': 74.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00043914',
#               'value': 64.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00044412',
#               'value': 53.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00044735',
#               'value': 71.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00045968',
#               'value': 46.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00046377',
#               'value': 64.0},
#              {'attributes': ',,0,0700',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00046657',
#               'value': 54.0},
#              {'attributes': ',,0,1500',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00047228',
#               'value': 69.0},
#              {'attributes': ',,0,1630',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00047741',
#               'value': 67.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00047874',
#               'value': 78.0},
#              {'attributes': ',,0,1600',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USC00049378',
#               'value': 70.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USR0000CALP',
#               'value': 68.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USR0000CAMM',
#               'value': 73.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USR0000CCAM',
#               'value': 62.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USR0000CCAS',
#               'value': 68.0},
#              {'attributes': 'H,,U,',
#               'datatype': 'TMAX',
#               'date': '2005-01-24T00:00:00',
#               'station': 'GHCND:USR0000CDES',
#               'value': 65.0}]}

# %%
response1 = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/locations?datasetid=GHCND&locationcategoryid=CNTY',headers = {'token':Token}).json()
pprint(response1)
# Out:
# {'metadata': {'resultset': {'count': 3137, 'limit': 25, 'offset': 1}},
#  'results': [{'datacoverage': 1,
#               'id': 'FIPS:01001',
#               'maxdate': '2020-09-29',
#               'mindate': '1900-01-01',
#               'name': 'Autauga County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01003',
#               'maxdate': '2020-10-01',
#               'mindate': '1912-05-15',
#               'name': 'Baldwin County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01005',
#               'maxdate': '2020-10-01',
#               'mindate': '1892-06-01',
#               'name': 'Barbour County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01007',
#               'maxdate': '2020-10-01',
#               'mindate': '1916-12-15',
#               'name': 'Bibb County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01009',
#               'maxdate': '2020-10-01',
#               'mindate': '1894-08-21',
#               'name': 'Blount County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01011',
#               'maxdate': '2020-09-30',
#               'mindate': '1892-05-01',
#               'name': 'Bullock County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01013',
#               'maxdate': '2020-09-25',
#               'mindate': '1900-10-01',
#               'name': 'Butler County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01015',
#               'maxdate': '2020-10-01',
#               'mindate': '1903-02-01',
#               'name': 'Calhoun County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01017',
#               'maxdate': '2020-07-31',
#               'mindate': '1944-10-19',
#               'name': 'Chambers County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01019',
#               'maxdate': '2020-10-01',
#               'mindate': '1941-08-01',
#               'name': 'Cherokee County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01021',
#               'maxdate': '2020-10-01',
#               'mindate': '1893-02-01',
#               'name': 'Chilton County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01023',
#               'maxdate': '2020-09-30',
#               'mindate': '1891-11-01',
#               'name': 'Choctaw County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01025',
#               'maxdate': '2020-10-01',
#               'mindate': '1891-09-01',
#               'name': 'Clarke County, AL'},
#              {'datacoverage': 0.9881,
#               'id': 'FIPS:01027',
#               'maxdate': '2019-10-31',
#               'mindate': '1940-03-18',
#               'name': 'Clay County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01029',
#               'maxdate': '2020-10-01',
#               'mindate': '1941-08-01',
#               'name': 'Cleburne County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01031',
#               'maxdate': '2020-10-01',
#               'mindate': '1893-03-01',
#               'name': 'Coffee County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01033',
#               'maxdate': '2020-10-01',
#               'mindate': '1893-01-01',
#               'name': 'Colbert County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01035',
#               'maxdate': '2020-09-30',
#               'mindate': '1929-04-01',
#               'name': 'Conecuh County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01037',
#               'maxdate': '2020-10-01',
#               'mindate': '1895-11-01',
#               'name': 'Coosa County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01039',
#               'maxdate': '2020-10-01',
#               'mindate': '1912-10-05',
#               'name': 'Covington County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01041',
#               'maxdate': '2020-09-30',
#               'mindate': '1930-07-14',
#               'name': 'Crenshaw County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01043',
#               'maxdate': '2020-10-01',
#               'mindate': '1907-08-01',
#               'name': 'Cullman County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01045',
#               'maxdate': '2020-10-01',
#               'mindate': '1902-05-01',
#               'name': 'Dale County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01047',
#               'maxdate': '2020-10-01',
#               'mindate': '1895-01-01',
#               'name': 'Dallas County, AL'},
#              {'datacoverage': 1,
#               'id': 'FIPS:01049',
#               'maxdate': '2020-10-01',
#               'mindate': '1893-01-01',
#               'name': 'DeKalb County, AL'}]}
