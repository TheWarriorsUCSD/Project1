# %%
# Dependencies and Setup
from census import Census
# from config import (census_key, gkey)
import gmaps
import numpy as np
import pandas as pd
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt
from pprint import pprint

# Import API key

from config import g_key
Token = 'kIhFoumHoyDXCthBMuPBenpMdGZfmqJI'

# %%
stationid=['GHCND:USW00003102',
'GHCND:USC00047470',
'GHCND:USC00042494',
'GHCND:USR0000CDVA',
'GHCND:USR0000CDUN',
'GHCND:USS0020L06S',
'GHCND:USC00047723',
'GHCND:USR0000CMOR',
'GHCND:USC00043251',
'GHCND:USC00043256',
'GHCND:USR0000CBZE',
'GHCND:USR0000CASC',
'GHCND:USR0000CBLQ',
'GHCND:USW00093112',
'GHCND:US1CASD0100',
'GHCND:US1CASD0038',
'GHCND:USR0000COAB',
'GHCND:US1CASH0009',
'GHCND:USC00042467',
'GHCND:USC00041916',
'GHCND:USC00045233',
'GHCND:US1CAMA0008',
'GHCND:US1CABT0032',
'GHCND:US1CABT0010',
'GHCND:USR0000CLDR',
'GHCND:USR0000CSNL',
'GHCND:USC00042920',
'GHCND:USR0000CABS',
'GHCND:USC00041886',
'GHCND:USC00043761',
'GHCND:USC00047085',
'GHCND:US1CAPM0002',
'GHCND:USR0000CBOG',
'GHCND:USC00041244',
'GHCND:USW00053144',
'GHCND:USR0000CDMC',
'GHCND:US1CATM0005',
'GHCND:USC00048353',
'GHCND:USS0020H06S',
'GHCND:USR0000CTIM',
'GHCND:USR0000CJUN',
'GHCND:USR0000CBUL',
'GHCND:USC00041476']
stationid
# Out:
# ['GHCND:USW00003102',
#  'GHCND:USC00047470',
#  'GHCND:USC00042494',
#  'GHCND:USR0000CDVA',
#  'GHCND:USR0000CDUN',
#  'GHCND:USS0020L06S',
#  'GHCND:USC00047723',
#  'GHCND:USR0000CMOR',
#  'GHCND:USC00043251',
#  'GHCND:USC00043256',
#  'GHCND:USR0000CBZE',
#  'GHCND:USR0000CASC',
#  'GHCND:USR0000CBLQ',
#  'GHCND:USW00093112',
#  'GHCND:US1CASD0100',
#  'GHCND:US1CASD0038',
#  'GHCND:USR0000COAB',
#  'GHCND:US1CASH0009',
#  'GHCND:USC00042467',
#  'GHCND:USC00041916',
#  'GHCND:USC00045233',
#  'GHCND:US1CAMA0008',
#  'GHCND:US1CABT0032',
#  'GHCND:US1CABT0010',
#  'GHCND:USR0000CLDR',
#  'GHCND:USR0000CSNL',
#  'GHCND:USC00042920',
#  'GHCND:USR0000CABS',
#  'GHCND:USC00041886',
#  'GHCND:USC00043761',
#  'GHCND:USC00047085',
#  'GHCND:US1CAPM0002',
#  'GHCND:USR0000CBOG',
#  'GHCND:USC00041244',
#  'GHCND:USW00053144',
#  'GHCND:USR0000CDMC',
#  'GHCND:US1CATM0005',
#  'GHCND:USC00048353',
#  'GHCND:USS0020H06S',
#  'GHCND:USR0000CTIM',
#  'GHCND:USR0000CJUN',
# ...

# %%
county = 'San Diego'
base_url = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?'
query_url = base_url+f'locationid=ZIP:28801&startdate=2010-05-01&enddate=2010-05-01'

response = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GSOM&datatypeid=TAVG&units=standard&limit=1000&locationid=FIPS:06073&startdate=2005-01-01&enddate=2005-12-30',headers = {'token':Token}).json()
pprint(response)
#data?datasetid=GSOM&datatypeid=TAVG&units=standard&limit=1000&locationid=FIPS:06&startdate=2006-01-01&enddate=2006-02-01
# Out:
# {'metadata': {'resultset': {'count': 437, 'limit': 1000, 'offset': 1}},
#  'results': [{'attributes': '3,0',
#               'datatype': 'TAVG',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00040983',
#               'value': 56.4},
#              {'attributes': ',0',
#               'datatype': 'TAVG',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00041424',
#               'value': 48.2},
#              {'attributes': '1,0',
#               'datatype': 'TAVG',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00042239',
#               'value': 41.7},
#              {'attributes': '3,0',
#               'datatype': 'TAVG',
#               'date': '2005-01-01T00:00:00',
#               'station': 'GHCND:USC00042706',
#               'value': 56.1},
#              {'attributes': '2,0',
#               'datatype': 'TAVG',
#               'date': '2005-01-01T00:00:00',
# ...

# %%
response1 = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/datacategories?datasetid=GSOM&locationid=FIPS:06073',headers = {'token':Token}).json()
pprint(response1)
# Out:
# {'metadata': {'resultset': {'count': 6, 'limit': 25, 'offset': 1}},
#  'results': [{'id': 'COMP', 'name': 'Computed'},
#              {'id': 'EVAP', 'name': 'Evaporation'},
#              {'id': 'PRCP', 'name': 'Precipitation'},
#              {'id': 'SUN', 'name': 'Sunshine'},
#              {'id': 'TEMP', 'name': 'Air Temperature'},
#              {'id': 'WIND', 'name': 'Wind'}]}

# %%
response2 = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/locations?datasetid=GSOM',headers = {'token':Token}).json()
pprint(response2)
# Out:
# {'metadata': {'resultset': {'count': 28419, 'limit': 25, 'offset': 1}},
#  'results': [{'datacoverage': 0.7734,
#               'id': 'CITY:AE000001',
#               'maxdate': '2020-07-01',
#               'mindate': '1983-06-01',
#               'name': 'Abu Dhabi, AE'},
#              {'datacoverage': 0.9819,
#               'id': 'CITY:AE000002',
#               'maxdate': '2020-08-01',
#               'mindate': '1944-04-01',
#               'name': 'Ajman, AE'},
#              {'datacoverage': 0.9819,
#               'id': 'CITY:AE000003',
#               'maxdate': '2020-08-01',
#               'mindate': '1944-04-01',
#               'name': 'Dubai, AE'},
#              {'datacoverage': 0.9819,
#               'id': 'CITY:AE000006',
#               'maxdate': '2020-08-01',
#               'mindate': '1944-04-01',
#               'name': 'Sharjah, AE'},
#              {'datacoverage': 0.9969,
#               'id': 'CITY:AF000007',
#               'maxdate': '2004-05-01',
# ...
